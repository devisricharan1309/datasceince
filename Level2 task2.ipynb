# %% [markdown]
# # LEVEL 2 TASK 2
# # TASK : PRICE RANGE ANALYSIS

# %% [raw]
# Determine the most common price for all restaurants.
# Let's use the .mode() attribute to find out the most common price, because we can have many modes, we used [0] because we took the most common price .
# Calculate the average rating for each price category.
# We can use .mean() to calculate the mean score. We would also round the answer to three decimal places.
# Identify the color that represents the highest average price.
# For the above task, we got the highest average using idxmax(a).
# For a Panda array, say one column, idxmax() returns the row identifier (index) of the maximum value.
# Note that idxmax() returns the first occurrence of the largest value. If multiple rows have the same maximum value, it returns the first row found in the data frame or sequence. After that, we represented the middle grade in pink and the highest grade in yellow.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Dataset .csv")

# %%
most_common_price_range = df['Price range'].mode()[0]
print(f"Most Common Price Range: {most_common_price_range}")
# Out:
# Most Common Price Range: 1.0

# %%
avg_rating_by_price_range = df.groupby('Price range')['Aggregate rating'].mean()
print("Average rating for each price range:")
print(round(avg_rating_by_price_range,3))
# Out:
# Average rating for each price range:
# Price range
# 1.0    2.308
# 2.0    3.111
# 3.0    3.754
# 4.0    3.885
# Name: Aggregate rating, dtype: float64

# %%
highest_avg_rating_color = avg_rating_by_price_range.idxmax()
plt.bar(avg_rating_by_price_range.index, avg_rating_by_price_range, color='pink')
plt.bar(highest_avg_rating_color, avg_rating_by_price_range[highest_avg_rating_color], color='yellow')
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
plt.title('Average Rating by Price Range')
plt.show()
